# %% [markdown]
# ## 引入库

# %%
# %matplotlib inline
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.preprocessing import image
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Input
from keras.applications.vgg16 import preprocess_input
# from keras.utils import multi_gpu_model
from tensorflow.python.keras.utils.multi_gpu_utils import multi_gpu_model
import numpy as np
import json

# %% [markdown]
# ## 设置参数值

# %%
batch_size = 40
epochs = 200

img_width, img_height = 224, 224

input_tensor = Input(shape=(224,224,3))

nb_training_samples = 1600
nb_validation_samples = 400

# %% [markdown]
# ## 配置训练和测试集

# %%
training_data_dir = './melspectrograms/training'

training_datagen = image.ImageDataGenerator(
    rescale=1./255)

training_generator = training_datagen.flow_from_directory(
    training_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size)

validation_data_dir ='./melspectrograms/testing/'

validation_datagen = image.ImageDataGenerator(
    rescale=1./255)

validation_generator = validation_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 1852 images belonging to 50 classes.
# Found 713 images belonging to 50 classes.

# %% [markdown]
# ## 加载底层模型

# %%
base_model = VGG16(weights='imagenet', include_top=False, input_tensor=input_tensor)
print('Model loaded.')
base_model.summary()
# Out:
# Model loaded.
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 建立顶层模型

# %%
type(base_model.output_shape)
base_model.output_shape[1:]
# Out:
# (7, 7, 512)

# %%
top_model = Sequential()
top_model.add(Flatten(input_shape=base_model.output_shape[1:]))
top_model.add(Dense(256, activation='relu'))
top_model.add(Dropout(0.5))
top_model.add(Dense(50, activation='softmax'))
top_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 256)               6422784
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 50)                12850
#
# =================================================================
# Total params: 6,435,634
# Trainable params: 6,435,634
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 把底层和顶层融合

# %%
model = Model(inputs=base_model.input, outputs=top_model(base_model.output))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  sequential (Sequential)     (None, 50)                6435634
#
# =================================================================
# Total params: 21,150,322
# Trainable params: 21,150,322
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 查看GPU是否可用

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 236809162005663553
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 3667263488
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 14566086515545787331
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]

# %% [markdown]
# ## 模型预编译

# %%
num_layers_to_freeze = 15

# %%
from keras import metrics
from tensorflow.keras import optimizers

def top_5_accuracy(y_true, y_pred):
    return metrics.top_k_categorical_accuracy(y_true, y_pred, k=5)

for layer in model.layers[:num_layers_to_freeze]:
    # print(layer.name)
    layer.trainable = False

# optimizer=optimizers.SGD(lr=1e-4, momentum=0.9, decay=1e-6, nesterov=True)
model.compile(optimizer=optimizers.SGD(learning_rate=1e-4, momentum=0.9), 
                      loss='categorical_crossentropy', 
                      metrics=['accuracy', top_5_accuracy])

# serialize model to JSON
model_json = model.to_json()
model_filename = "vgg16_model_{}_frozen_layers.json".format(num_layers_to_freeze)
with open(model_filename, "w") as json_file:
    json_file.write(model_json)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  sequential (Sequential)     (None, 50)                6435634
#
# =================================================================
# Total params: 21,150,322
# Trainable params: 13,515,058
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %% [markdown]
# ## 模型训练

# %%
from keras.callbacks import ModelCheckpoint, TensorBoard
from time import time

tensorboard = TensorBoard(log_dir="logs/layers_frozen_{}".format(num_layers_to_freeze))

# checkpoint
filepath="esc50_vgg16_stft_weights_train_last_2_base_layers.best.hdf5"
best_model_checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [best_model_checkpoint, tensorboard]

model.fit(
    training_generator,
    steps_per_epoch=nb_training_samples/batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples/batch_size,
    callbacks=callbacks_list)
# Out:
# Epoch 1/200
# 40/40 [==============================] - ETA: 0s - loss: 4.0378 - accuracy: 0.0261 - top_5_accuracy: 0.1088WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 20s 335ms/step - loss: 4.0378 - accuracy: 0.0261 - top_5_accuracy: 0.1088 - val_loss: 3.8606 - val_accuracy: 0.0450 - val_top_5_accuracy: 0.1450
# Epoch 2/200
# 40/40 [==============================] - ETA: 0s - loss: 3.8661 - accuracy: 0.0363 - top_5_accuracy: 0.1667WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s
- top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 177ms/step - loss: 0.1629 - accuracy: 0.9599 - top_5_accuracy: 1.0000 - val_loss: 0.2464 - val_accuracy: 0.9300 - val_top_5_accuracy: 0.9875
# Epoch 119/200
# 40/40 [==============================] - ETA: 0s - loss: 0.1703 - accuracy: 0.9542 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 177ms/step - loss: 0.1703 - accuracy: 0.9542 - top_5_accuracy: 1.0000 - val_loss: 0.2469 - val_accuracy: 0.9425 - val_top_5_accuracy: 0.9850
# Epoch 120/200
# 40/40 [==============================] - ETA: 0s - loss: 0.1657 - accuracy: 0.9542 - top_5_accuracy: 0.9987WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 177ms/step - loss: 0.1657 - accuracy: 0.9542 - top_5_accuracy: 0.9987 - val_loss: 0.1596 - val_accuracy: 0.9550 - val_top_5_accuracy: 0.9925
# Epoch 121/200
# 40/40 [==============================] - ETA: 0s - loss: 0.1616 - accuracy: 0.9625 - top_5_accuracy: 0.9987WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 177ms/step - loss: 0.1616 - accuracy: 0.9625 - top_5_accuracy: 0.9987 - val_loss: 0.1940 - val_accuracy: 0.9500 - val_top_5_accuracy: 0.9900
# Epoch 122/200
# 39/40 [============================>.] - ETA: 0s - loss: 0.1544 - accuracy: 0.9647 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 176ms/step - loss: 0.1563 - accuracy: 0.9637 - top_5_accuracy: 1.0000 - val_loss: 0.2138 - val_accuracy: 0.9375 - val_top_5_accuracy: 0.9875
# Epoch 123/200
# 40/40 [==============================] - ETA: 0s - loss: 0.1488 - accuracy: 0.9631 - top_5_accuracy: 0.9987WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 177ms/step - loss: 0.1488 - accuracy: 0.9631 - top_5_accuracy: 0.9987 - val_loss: 0.2628 - val_accuracy: 0.9350 - val_top_5_accuracy: 0.9800
# Epoch 124/200
# 40/40 [==============================] - ETA: 0s - loss: 0.1489 - accuracy: 0.9663 - top_5_accuracy: 0.9994WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 177ms/step - loss: 0.1489 - accuracy: 0.9663 - top_5_accuracy: 0.9994 - val_loss: 0.2156 - val_accuracy: 0.9450 - val_top_5_accuracy: 0.9875
# Epoch 125/200
# 40/40 [==============================] - ETA: 0s - loss: 0.1510 - accuracy: 0.9644 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 177ms/step - loss: 0.1510 - accuracy: 0.9644 - top_5_accuracy: 1.0000 - val_loss: 0.2337 - val_accuracy: 0.9450 - val_top_5_accuracy: 0.9875
# Epoch 126/200
# ...
# 40/40 [==============================] - 7s 178ms/step - loss: 0.0891 - accuracy: 0.9850 - top_5_accuracy: 1.0000 - val_loss: 0.2168 - val_accuracy: 0.9475 - val_top_5_accuracy: 0.9875
# Epoch 160/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0982 - accuracy: 0.9752 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 176ms/step - loss: 0.0982 - accuracy: 0.9752 - top_5_accuracy: 1.0000 - val_loss: 0.2123 - val_accuracy: 0.9375 - val_top_5_accuracy: 0.9875
# Epoch 161/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0985 - accuracy: 0.9790 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 176ms/step - loss: 0.0985 - accuracy: 0.9790 - top_5_accuracy: 1.0000 - val_loss: 0.1721 - val_accuracy: 0.9475 - val_top_5_accuracy: 0.9925
# Epoch 162/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0987 - accuracy: 0.9737 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 178ms/step - loss: 0.0987 - accuracy: 0.9737 - top_5_accuracy: 1.0000 - val_loss: 0.1735 - val_accuracy: 0.9525 - val_top_5_accuracy: 0.9900
# Epoch 163/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0773 - accuracy: 0.9873 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 176ms/step - loss: 0.0773 - accuracy: 0.9873 - top_5_accuracy: 1.0000 - val_loss: 0.2241 - val_accuracy: 0.9400 - val_top_5_accuracy: 0.9875
# Epoch 164/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0830 - accuracy: 0.9860 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 177ms/step - loss: 0.0830 - accuracy: 0.9860 - top_5_accuracy: 1.0000 - val_loss: 0.1928 - val_accuracy: 0.9475 - val_top_5_accuracy: 0.9875
# Epoch 165/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0869 - accuracy: 0.9822 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 177ms/step - loss: 0.0869 - accuracy: 0.9822 - top_5_accuracy: 1.0000 - val_loss: 0.1857 - val_accuracy: 0.9375 - val_top_5_accuracy: 0.9900
# Epoch 166/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0903 - accuracy: 0.9777 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 176ms/step - loss: 0.0903 - accuracy: 0.9777 - top_5_accuracy: 1.0000 - val_loss: 0.2082 - val_accuracy: 0.9400 - val_top_5_accuracy: 0.9875
# Epoch 167/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0803 - accuracy: 0.9816 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 177ms/step - loss: 0.0803 - accuracy: 0.9816 - top_5_accuracy: 1.0000 - val_loss: 0.2029 - val_accuracy: 0.9450 - val_top_5_accuracy: 0.9850
# Epoch 168/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0947 - accuracy: 0.9803 - top_5_accuracy: 0.9994WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 175ms/step - loss: 0.0947 - accuracy: 0.9803 - top_5_accuracy: 0.9994 - val_loss: 0.1880 - val_accuracy: 0.9475 - val_top_5_accuracy: 0.9900
# Epoch 169/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0955 - accuracy: 0.9758 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 177ms/step - loss: 0.0955 - accuracy: 0.9758 - top_5_accuracy: 1.0000 - val_loss: 0.2308 - val_accuracy: 0.9400 - val_top_5_accuracy: 0.9850
# Epoch 170/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0872 - accuracy: 0.9771 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 176ms/step - loss: 0.0872 - accuracy: 0.9771 - top_5_accuracy: 1.0000 - val_loss: 0.1738 - val_accuracy: 0.9525 - val_top_5_accuracy: 0.9875
# Epoch 171/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0891 - accuracy: 0.9777 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 177ms/step - loss: 0.0891 - accuracy: 0.9777 - top_5_accuracy: 1.0000 - val_loss: 0.1305 - val_accuracy: 0.9600 - val_top_5_accuracy: 0.9925
# Epoch 172/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0822 - accuracy: 0.9860 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 176ms/step - loss: 0.0822 - accuracy: 0.9860 - top_5_accuracy: 1.0000 - val_loss: 0.2048 - val_accuracy: 0.9450 - val_top_5_accuracy: 0.9875
# Epoch 173/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0794 - accuracy: 0.9822 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 176ms/step - loss: 0.0794 - accuracy: 0.9822 - top_5_accuracy: 1.0000 - val_loss: 0.2435 - val_accuracy: 0.9400 - val_top_5_accuracy: 0.9850
# Epoch 174/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0819 - accuracy: 0.9835 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 179ms/step - loss: 0.0819 - accuracy: 0.9835 - top_5_accuracy: 1.0000 - val_loss: 0.1748 - val_accuracy: 0.9425 - val_top_5_accuracy: 0.9900
# Epoch 175/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0854 - accuracy: 0.9787 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 178ms/step - loss: 0.0854 - accuracy: 0.9787 - top_5_accuracy: 1.0000 - val_loss: 0.2461 - val_accuracy: 0.9375 - val_top_5_accuracy: 0.9875
# Epoch 176/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0809 - accuracy: 0.9831 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 177ms/step - loss: 0.0809 - accuracy: 0.9831 - top_5_accuracy: 1.0000 - val_loss: 0.1819 - val_accuracy: 0.9450 - val_top_5_accuracy: 0.9875
# Epoch 177/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0756 - accuracy: 0.9875 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 178ms/step - loss: 0.0756 - accuracy: 0.9875 - top_5_accuracy: 1.0000 - val_loss: 0.1832 - val_accuracy: 0.9375 - val_top_5_accuracy: 0.9900
# Epoch 178/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0815 - accuracy: 0.9828 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 176ms/step - loss: 0.0815 - accuracy: 0.9828 - top_5_accuracy: 1.0000 - val_loss: 0.1740 - val_accuracy: 0.9325 - val_top_5_accuracy: 0.9925
# Epoch 179/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0761 - accuracy: 0.9803 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 178ms/step - loss: 0.0761 - accuracy: 0.9803 - top_5_accuracy: 1.0000 - val_loss: 0.2345 - val_accuracy: 0.9350 - val_top_5_accuracy: 0.9875
# Epoch 180/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0862 - accuracy: 0.9784 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 177ms/step - loss: 0.0862 - accuracy: 0.9784 - top_5_accuracy: 1.0000 - val_loss: 0.1399 - val_accuracy: 0.9550 - val_top_5_accuracy: 0.9950
# Epoch 181/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0772 - accuracy: 0.9828 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 177ms/step - loss: 0.0772 - accuracy: 0.9828 - top_5_accuracy: 1.0000 - val_loss: 0.1699 - val_accuracy: 0.9425 - val_top_5_accuracy: 0.9925
# Epoch 182/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0730 - accuracy: 0.9854 - top_5_accuracy: 0.9987WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 177ms/step - loss: 0.0730 - accuracy: 0.9854 - top_5_accuracy: 0.9987 - val_loss: 0.1787 - val_accuracy: 0.9450 - val_top_5_accuracy: 0.9875
# Epoch 183/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0793 - accuracy: 0.9790 - top_5_accuracy: 0.9994WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 176ms/step - loss: 0.0793 - accuracy: 0.9790 - top_5_accuracy: 0.9994 - val_loss: 0.2596 - val_accuracy: 0.9275 - val_top_5_accuracy: 0.9825
# Epoch 184/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0732 - accuracy: 0.9835 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 177ms/step - loss: 0.0732 - accuracy: 0.9835 - top_5_accuracy: 1.0000 - val_loss: 0.1927 - val_accuracy: 0.9475 - val_top_5_accuracy: 0.9875
# Epoch 185/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0787 - accuracy: 0.9828 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 177ms/step - loss: 0.0787 - accuracy: 0.9828 - top_5_accuracy: 1.0000 - val_loss: 0.2056 - val_accuracy: 0.9475 - val_top_5_accuracy: 0.9900
# Epoch 186/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0707 - accuracy: 0.9869 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 178ms/step - loss: 0.0707 - accuracy: 0.9869 - top_5_accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9500 - val_top_5_accuracy: 0.9900
# Epoch 187/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0677 - accuracy: 0.9866 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 177ms/step - loss: 0.0677 - accuracy: 0.9866 - top_5_accuracy: 1.0000 - val_loss: 0.1311 - val_accuracy: 0.9575 - val_top_5_accuracy: 0.9950
# Epoch 188/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0721 - accuracy: 0.9866 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 178ms/step - loss: 0.0721 - accuracy: 0.9866 - top_5_accuracy: 1.0000 - val_loss: 0.2165 - val_accuracy: 0.9400 - val_top_5_accuracy: 0.9875
# Epoch 189/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0663 - accuracy: 0.9844 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 180ms/step - loss: 0.0663 - accuracy: 0.9844 - top_5_accuracy: 1.0000 - val_loss: 0.1987 - val_accuracy: 0.9475 - val_top_5_accuracy: 0.9875
# Epoch 190/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0631 - accuracy: 0.9879 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 179ms/step - loss: 0.0631 - accuracy: 0.9879 - top_5_accuracy: 1.0000 - val_loss: 0.2568 - val_accuracy: 0.9100 - val_top_5_accuracy: 0.9850
# Epoch 191/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0713 - accuracy: 0.9835 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 179ms/step - loss: 0.0713 - accuracy: 0.9835 - top_5_accuracy: 1.0000 - val_loss: 0.1754 - val_accuracy: 0.9400 - val_top_5_accuracy: 0.9900
# Epoch 192/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0761 - accuracy: 0.9809 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 179ms/step - loss: 0.0761 - accuracy: 0.9809 - top_5_accuracy: 1.0000 - val_loss: 0.1943 - val_accuracy: 0.9400 - val_top_5_accuracy: 0.9900
# Epoch 193/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0613 - accuracy: 0.9856 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 178ms/step - loss: 0.0613 - accuracy: 0.9856 - top_5_accuracy: 1.0000 - val_loss: 0.2179 - val_accuracy: 0.9400 - val_top_5_accuracy: 0.9850
# Epoch 194/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0617 - accuracy: 0.9905 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 178ms/step - loss: 0.0617 - accuracy: 0.9905 - top_5_accuracy: 1.0000 - val_loss: 0.2011 - val_accuracy: 0.9425 - val_top_5_accuracy: 0.9925
# Epoch 195/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0665 - accuracy: 0.9854 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 177ms/step - loss: 0.0665 - accuracy: 0.9854 - top_5_accuracy: 1.0000 - val_loss: 0.1992 - val_accuracy: 0.9425 - val_top_5_accuracy: 0.9925
# Epoch 196/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0612 - accuracy: 0.9866 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 177ms/step - loss: 0.0612 - accuracy: 0.9866 - top_5_accuracy: 1.0000 - val_loss: 0.1806 - val_accuracy: 0.9475 - val_top_5_accuracy: 0.9875
# Epoch 197/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0664 - accuracy: 0.9866 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 179ms/step - loss: 0.0664 - accuracy: 0.9866 - top_5_accuracy: 1.0000 - val_loss: 0.1849 - val_accuracy: 0.9475 - val_top_5_accuracy: 0.9875
# Epoch 198/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0687 - accuracy: 0.9847 - top_5_accuracy: 0.9994WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 178ms/step - loss: 0.0687 - accuracy: 0.9847 - top_5_accuracy: 0.9994 - val_loss: 0.2027 - val_accuracy: 0.9400 - val_top_5_accuracy: 0.9875
# Epoch 199/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0591 - accuracy: 0.9866 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 177ms/step - loss: 0.0591 - accuracy: 0.9866 - top_5_accuracy: 1.0000 - val_loss: 0.1821 - val_accuracy: 0.9350 - val_top_5_accuracy: 0.9900
# Epoch 200/200
# 40/40 [==============================] - ETA: 0s - loss: 0.0704 - accuracy: 0.9866 - top_5_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 40/40 [==============================] - 7s 178ms/step - loss: 0.0704 - accuracy: 0.9866 - top_5_accuracy: 1.0000 - val_loss: 0.1989 - val_accuracy: 0.9425 - val_top_5_accuracy: 0.9925

# %% [markdown]
# ## 获取测试得到的前k个概率

# %%
def get_top_k_predictions(preds, label_map, k=5, print_flag=False):
    sorted_array = np.argsort(preds)[::-1]
    top_k = sorted_array[:k]
    label_map_flip = dict((v,k) for k,v in label_map.items())
    
    y_pred = []
    for label_index in top_k:
        if print_flag:
            print("{} ({})".format(label_map_flip[label_index], preds[label_index]))
        y_pred.append(label_map_flip[label_index])
        
    return y_pred

# %%
label_map = (training_generator.class_indices)
 
# json = json.dumps(label_map)
# f = open("cough_label_map.json","w")
# f.write(json)
# f.close()

img_path = './melspectrograms/testing/vacuum_cleaner/5-182007-A-36.png'

img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)* 1./255

preds = model.predict(x)[0]

get_top_k_predictions(preds, label_map, k=3)
# Out:
# ['vacuum_cleaner', 'crickets', 'washing_machine']

# %% [markdown]
# ## 存储模型

# %%
model.save('ESC50_94.h5')

# %% [markdown]
# ## 计算并绘制混淆矩阵

# %%
import itertools
import matplotlib.pyplot as plt
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

#     print(cm)
    plt.figure(figsize=(24,24))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    ## 保存模块
    # f = plt.gcf()  #获取当前图像
    # f.savefig('cm.png')
    # f.clear()  #释放内存

# %%
from sklearn.metrics import confusion_matrix
import os

testing_dir = './melspectrograms/testing/'

y_true = []
y_pred = []
for label in label_map.keys():
    file_list = os.listdir(testing_dir + label)
    for file_name in file_list:
        img_path = testing_dir + label + '/' + file_name
        
        img = image.load_img(img_path, target_size=(224, 224))
        
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)* 1./255
        
        preds = model.predict(x)[0]
        
        y_true.append(label)
        y_pred.append(get_top_k_predictions(preds, label_map, k=1)[0])
        
cm = confusion_matrix(y_true, y_pred)
plot_confusion_matrix(cm, sorted(label_map.keys()), normalize=True)
# Out:
# Normalized confusion matrix

# %% [markdown]
# ## 模型载入及测试

# %%
from keras.models import load_model

# %%
model_test = load_model('ESC50_94.h5', custom_objects={'top_5_accuracy': top_5_accuracy} )

# %%
img_path = './melspectrograms/testing/insects/1-73585-A-7.png'

img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)* 1./255

preds = model_test.predict(x)[0]

# %%
preds
# Out:
# array([1.3089745e-02, 9.4614160e-07, 2.1011817e-06, 4.5234292e-06,
#        2.8062095e-07, 1.8467421e-06, 1.1176526e-03, 1.5205190e-06,
#        8.8312427e-06, 1.1666104e-05, 1.8380762e-06, 2.1736369e-05,
#        1.5065628e-04, 1.0699693e-05, 1.1027605e-05, 9.2775972e-06,
#        3.4311990e-06, 1.8830796e-06, 1.2271061e-05, 2.1005917e-05,
#        1.6660947e-06, 2.1207657e-06, 4.1149877e-05, 2.4846550e-08,
#        9.4834940e-07, 2.0841642e-06, 4.5346674e-06, 2.7852693e-05,
#        3.9513750e-05, 2.2066666e-05, 9.7602749e-01, 2.7609942e-05,
#        6.0250409e-07, 4.5914035e-06, 1.0756281e-05, 6.1032788e-06,
#        3.5936648e-06, 3.2166602e-07, 1.6049815e-05, 6.5939363e-05,
#        1.4326494e-06, 3.2198463e-05, 2.0826690e-05, 2.2653203e-06,
#        4.6938311e-04, 6.4278079e-06, 5.1742191e-03, 1.9862095e-03,
#        1.6906711e-07, 1.5190656e-03], dtype=float32)

# %%
max_index = np.argmax(np.array(preds))

# %%
max_index
# Out:
# 30

# %%
label_map
# Out:
# {'airplane': 0,
#  'breathing': 1,
#  'brushing_teeth': 2,
#  'can_opening': 3,
#  'car_horn': 4,
#  'cat': 5,
#  'chainsaw': 6,
#  'chirping_birds': 7,
#  'church_bells': 8,
#  'clapping': 9,
#  'clock_alarm': 10,
#  'clock_tick': 11,
#  'coughing': 12,
#  'cow': 13,
#  'crackling_fire': 14,
#  'crickets': 15,
#  'crow': 16,
#  'crying_baby': 17,
#  'dog': 18,
#  'door_wood_creaks': 19,
#  'door_wood_knock': 20,
#  'drinking_sipping': 21,
#  'engine': 22,
#  'fireworks': 23,
#  'footsteps': 24,
#  'frog': 25,
#  'glass_breaking': 26,
#  'hand_saw': 27,
#  'helicopter': 28,
#  'hen': 29,
#  'insects': 30,
#  'keyboard_typing': 31,
#  'laughing': 32,
#  'mouse_click': 33,
#  'pig': 34,
#  'pouring_water': 35,
#  'rain': 36,
#  'rooster': 37,
#  'sea_waves': 38,
#  'sheep': 39,
#  'siren': 40,
#  'sneezing': 41,
#  'snoring': 42,
#  'thunderstorm': 43,
#  'toilet_flush': 44,
#  'train': 45,
#  'vacuum_cleaner': 46,
#  'washing_machine': 47,
#  'water_drops': 48,
#  'wind': 49}
